# %%
import pandas as pd

dummy = pd.read_csv("NSDUH_2020_Tab.txt", sep='\t')
# Out:
# /var/folders/gp/xs_xkf814zx898m2wdld0hw40000gn/T/ipykernel_12381/1612466860.py:3: DtypeWarning: Columns (2726) have mixed types. Specify dtype option on import or set low_memory=False.
#   dummy = pd.read_csv("NSDUH_2020_Tab.txt", sep='\t')

# %%
dummy.head(10)
# Out:
#    QUESTID2    FILEDATE  CIGEVER  CIGOFRSM  CIGWILYR  CIGTRY  CIGYFU  CIGMFU  \
# 0  10000182  10/25/2021        1        99        99      16    9999      99
# 1  10001831  10/25/2021        1        99        99       8    9999      99
# 2  10002722  10/25/2021        2        99        99     991    9991      91
# 3  10002897  10/25/2021        2        99        99     991    9991      91
# 4  10004677  10/25/2021        2         4         4     991    9991      91
# 5  10004796  10/25/2021        2        99        99     991    9991      91
# 6  10005265  10/25/2021        1        99        99      15    9999      99
# 7  10005369  10/25/2021        2        99        99     991    9991      91
# 8  10007045  10/25/2021        2        99        99     991    9991      91
# 9  10007700  10/25/2021        1        99        99      16    9999      99
#
#    CIGREC  CIG30USE  ...  GOVTPROG  INCOME  POVERTY3  PDEN10  COUTYP4  \
# ...

# %%
marijuana_df = dummy[["MJEVER", "MJAGE", "MJYFU", "MJMFU", "MJREC", "MJYRTOT", "MRTOTFG", "MJFQFLG","MRBSTWAY", "MRDAYPYR", "MRDAYPMO","MRDAYPWK", "MJDAY30A", "MR30EST"]]

# %%
marijuana_df.to_csv("marijuana2020.csv")
