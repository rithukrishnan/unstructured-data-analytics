have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("1500postsshein.csv", on_bad_lines='skip')
#                                               biography  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
# 1500  WEAR YOUR WONDERFUL\n📸Get featured using #SHEI...
#
#                              businessCategoryName  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1496                                          NaN
# 1497                                          NaN
# 1498                                          NaN
# 1499                                          NaN
# 1500  Personal Goods & General Merchandise Stores
#
#                                                 caption  childPosts/0/caption  \
# 0     Hurry up, limited quantities available! Good t...                   NaN
# 1     Hit the club, get dressed to the nines, or hos...                   NaN
# 2     Make sure you set those calender reminders ‘cu...                   NaN
# 3     Today's outfit inspo 🌟\n\nShop Item #: 2965171...                   NaN
# 4     Milky way 🤍@serinaarodriguez\n\nShop Item #: 1...                   NaN
# ...                                                 ...                   ...
# 1496  We lilac this beautiful vibe so much! 💜  @mily...                   NaN
# 1497  Life on the beach ✨  @melissaarnoldi98\n\nShop...                   NaN
# 1498  Just livin’ life 🌴✨ @_fashionablynoble_\n\nSho...                   NaN
# 1499  Beach, tan, repeat 🙌  @cla.yaya\n\nShop Item #...                   NaN
# 1500                                                NaN                   NaN
#
#       childPosts/0/commentsCount  childPosts/0/dimensionsHeight  \
# 0                            NaN                            NaN
# 1                            0.0                         1080.0
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ...                          ...                            ...
# 1496                         NaN                            NaN
# 1497                         NaN                            NaN
# 1498                         NaN                            NaN
# 1499                         NaN                            NaN
# 1500                         NaN                            NaN
#
#       childPosts/0/dimensionsWidth  \
# 0                              NaN
# 1                           1080.0
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 1496                           NaN
# 1497                           NaN
# 1498                           NaN
# 1499                           NaN
# 1500                           NaN
#
#                                 childPosts/0/displayUrl  \
# 0                                                   NaN
# 1     https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
# 1500                                                NaN
#
#       childPosts/0/firstComment  childPosts/0/id  ...  \
# 0                           NaN              NaN  ...
# 1                           NaN     2.972830e+18  ...
# 2                           NaN              NaN  ...
# 3                           NaN              NaN  ...
# 4                           NaN              NaN  ...
# ...                         ...              ...  ...
# 1496                        NaN              NaN  ...
# 1497                        NaN              NaN  ...
# 1498                        NaN              NaN  ...
# 1499                        NaN              NaN  ...
# 1500                        NaN              NaN  ...
#
#                      relatedProfiles/79/profile_pic_url  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1496                                                NaN
# 1497                                                NaN
# 1498                                                NaN
# 1499                                                NaN
# 1500  https://scontent-dfw5-2.cdninstagram.com/v/t51...
#
#       relatedProfiles/79/username    shortCode                 timestamp  \
# 0                             NaN  ClYoNqbJMFq  2022-11-25T13:00:13.000Z
# 1                             NaN  ClBnZe-hsgM  2022-11-16T14:30:34.000Z
# 2                             NaN  ClQOq8cLopI  2022-11-22T06:44:19.000Z
# 3                             NaN  Clbyys4rmYG  2022-11-26T18:30:29.000Z
# 4                             NaN  ClbvX-YDYN7  2022-11-26T18:00:31.000Z
# ...                           ...          ...                       ...
# 1496                          NaN  Cf_rksbrRAU  2022-07-14T13:51:35.000Z
# 1497                          NaN  Cf_p2g0LBKg  2022-07-14T13:36:33.000Z
# 1498                          NaN  Cf_pvzaLYBv  2022-07-14T13:35:38.000Z
# 1499                          NaN  Cf_oMccL8xH  2022-07-14T13:22:04.000Z
# 1500                aislinnderbez          NaN                       NaN
#
#          type                                       url       username  \
# 0       Image  https://www.instagram.com/p/ClYoNqbJMFq/            NaN
# 1     Sidecar  https://www.instagram.com/p/ClBnZe-hsgM/            NaN
# 2       Video  https://www.instagram.com/p/ClQOq8cLopI/            NaN
# 3       Video  https://www.instagram.com/p/Clbyys4rmYG/            NaN
# 4       Image  https://www.instagram.com/p/ClbvX-YDYN7/            NaN
# ...       ...                                       ...            ...
# 1496    Image  https://www.instagram.com/p/Cf_rksbrRAU/            NaN
# 1497    Image  https://www.instagram.com/p/Cf_p2g0LBKg/            NaN
# 1498    Image  https://www.instagram.com/p/Cf_pvzaLYBv/            NaN
# 1499    Image  https://www.instagram.com/p/Cf_oMccL8xH/            NaN
# 1500      NaN   https://www.instagram.com/sheinofficial  sheinofficial
#
#       verified                                           videoUrl  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN  https://scontent-lhr8-1.cdninstagram.com/v/t66...
# 3          NaN  https://scontent-lhr8-2.cdninstagram.com/v/t50...
# 4          NaN                                                NaN
# ...        ...                                                ...
# 1496       NaN                                                NaN
# 1497       NaN                                                NaN
# 1498       NaN                                                NaN
# 1499       NaN                                                NaN
# 1500      True                                                NaN
#
#       videoViewCount
# 0                NaN
# 1                NaN
# 2            96654.0
# 3            16454.0
# 4                NaN
# ...              ...
# 1496             NaN
# 1497             NaN
# 1498             NaN
# 1499             NaN
# 1500             NaN
#
# [1501 rows x 1197 columns]

# %%
import json
  
# Opening JSON file
f = open('1500postsshein.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
for i in data:
    print(i)
  
# Closing file
f.close()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json
import csv
 
 
# Opening JSON file and loading the data
# into the variable data
with open('Ultimate1500.json') as json_file:
    data = json.load(json_file)
 
employee_data = data
 
# now we will open a file for writing
data_file = open('Ultimate1500.csv', 'w')
 
# create the csv writer object
csv_writer = csv.writer(data_file)
 
# Counter variable used for writing
# headers to the CSV file
count = 0
 
for emp in employee_data:
    if count == 0:
 
        # Writing headers of CSV file
        header = emp.keys()
        csv_writer.writerow(header)
        count += 1
 
    # Writing data of CSV file
    csv_writer.writerow(emp.values())
 
data_file.close()

# %%
import pandas as pd

dummy = pd.read_csv("Ultimate1500.csv")
dummy
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 dummy = pd.read_csv("Ultimate1500.csv")
#       4 dummy
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1255, in TextFileReader.read(self, nrows)
#    1253 nrows = validate_integer("nrows", nrows)
#    1254 try:
# -> 1255     index, columns, col_dict = self._engine.read(nrows)
#    1256 except Exception:
#    1257     self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 20 fields in line 6, saw 22
